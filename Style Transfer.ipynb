# %%
from style_transfer import *

# %matplotlib inline

# %%
# List styles or content
! ls
# Out:
# __pycache__
# content
# style
# Style Transfer.ipynb
# style_transfer.py
# stylized

# %%
# Initializes style transfer CNN as VGG19
vgg19 = init_vgg19(style_weights=None)

# %%
content_image, style_image = content_style_loader(content_path ="./content/Fz.jpg", 
                                                  style_path   ="./style/poly_bluepink.png")

# %%
canvas_saves = transfer_style(content_image, style_image, vgg19, 
                              iterations=4000, report=500, canvas=None)
# Out:
# Total Loss: 53170992.0lapsed:  1m 52s, Estimated Time Remaining: 13m  8s Iterations/s = 4.44
# Total Loss: 14790750.0Elapsed:  5m 22s, Estimated Time Remaining: 16m  8s Iterations/s = 3.10
# Total Loss: 7705342.5 Elapsed:  8m 20s, Estimated Time Remaining: 13m 54s Iterations/s = 3.00
# Total Loss: 4473506.5 Elapsed: 11m  8s, Estimated Time Remaining: 11m  8s Iterations/s = 2.99
# Total Loss: 2827176.5 Elapsed: 13m 57s, Estimated Time Remaining:  8m 22s Iterations/s = 2.99
# Total Loss: 1926761.625lapsed: 16m 46s, Estimated Time Remaining:  5m 35s Iterations/s = 2.98
# Total Loss: 1501104.5 Elapsed: 20m  4s, Estimated Time Remaining:  2m 52s Iterations/s = 2.91
# Total Loss: 1092720.25Elapsed: 23m 50s, Estimated Time Remaining:  0m  0s Iterations/s = 2.80

# %%
imshow(canvas_saves[4000])

# %%
imsave(canvas_saves[4000], path='./stylized/poly_bluepink_Fz.png')
